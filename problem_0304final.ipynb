# %% [markdown]
# ## Coding Problem #0304

# %% [markdown]
# ### "Policy support rate"

# %%
import numpy as np
import scipy.stats as st

# %% [markdown]
# #### Answer the following questions by providing Python code:

# %% [markdown]
# It is known that the overall policy support rate is 52%. <br>

# %%
p = 0.52

# %% [markdown]
# 1). What is the probability of support rate less than 50% when asked to 100 people? <br>
# HINT: Use sample proportion and Standard Normal distribution.

# %%
n=100
std_error = np.sqrt(p*(1-p)/n)
z = (0.5 - p)/std_error
st.norm.cdf(z)
# Out:
# 0.3444602779022302

# %% [markdown]
# 2). What is the probability of support rate less than 50% when asked to 300 people? <br>
# HINT: Use sample proportion and Standard Normal distribution.

# %%
n=300
std_error = np.sqrt(p*(1-p)/n)
z = (0.5 - p)/std_error
st.norm.cdf(z)
# Out:
# 0.24403704658262387

# %% [markdown]
# 3). Redo the calculations of 1) and 2) using the Binomial distribution. Then, compare.

# %%
# Redo of 1).
n=100
st.binom.cdf(0.5*n,n,p)
# Out:
# 0.3816199474102779

# %%
# Redo of 2).
n=300
st.binom.cdf(0.5*n,n,p)
# Out:
# 0.2624050639758823

# %%
#Again in this series, we notice that the results obtained with the binomial law are greater
#that the results obtained with the method of sample proportion and Standard Normal distribution

# %% [markdown]
# 4). Redo the calculations of 1) and 2) using the Poisson distribution. Then, compare.

# %%
# Redo of 1).
n1=100
lam= n1 * p
r = 0.5 * n1
st.poisson.cdf(r,lam)
# Out:
# 0.42632224798181584

# %%
# Redo of 2).
n2=300
lamb =n2*p
r = 0.5*n2
st.poisson.pmf(r,lamb2)
# Out:
# 0.028963908400405483

# %%
#The results of the Poisson law are even more insignificant than those of the sample proportion and Standard Normal distribution
#While the results obtained by the Binomial law are once again more important than the others
